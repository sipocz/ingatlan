# %% [markdown]
# <a href="https://colab.research.google.com/github/sipocz/ingatlan/blob/master/Dunahouse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import  BeautifulSoup


def querycity(city):
    print("------------------------------------------------")
    print("+    ",city.capitalize())
    url="https://dh.hu/elado-ingatlan/haz/"+city+"/-/100-mFt-ig/ordermode-3"
    res=requests.get(url)
    soup=BeautifulSoup(res.text,"html.parser")
    link=soup.select(".moreDetailsBox > a[href] ")
    urllist=soup.find_all("a", class_="listEstateWithPic")
    price=soup.select("span ")
    pricelist=soup.find_all(itemprop="price")

    out1=[]
    out2={}
    for i in enumerate(urllist):
        link="https://dh.hu"+i[1]['href']
        print(f"+{i[0]:>4}. {pricelist[i[0]].text:>10} :  {link:<1000}")
       # print(i[0],". ",pricelist[i[0]].text,link)
      
      
        out1.append([pricelist[i[0]].text,link])

        #out.append([urllist[i],pricelist[i]])
    
    print("----------------  END  ------------------------")


querycity("esztergom")
querycity("nagysap")
querycity("urom")
querycity("csobanka")
querycity("pilisjaszfalu")
querycity("mogyorosbanya")
querycity("piliscsaba")
querycity("csolnok")
querycity("zsambek")
querycity("gyermely")
querycity("szomor")
querycity("csobanka")
querycity("tinnye")
querycity("pilisvorosvar")
querycity("solymar")
querycity("perbal")
querycity("pilisborosjeno")
# Out:
# ------------------------------------------------
# +     Esztergom
# +   0. 99 500 000 Ft :  https://dh.hu/ingatlan/HZ017875/elado-haz-komarom-esztergom-megye-esztergom
# +   1. 99 000 000 Ft :  https://dh.hu/ingatlan/HZ010471/elado-haz-komarom-esztergom-megye-esztergom
# +   2. 96 500 000 Ft :  https://dh.hu/ingatlan/HZ025939/elado-haz-komarom-esztergom-megye-esztergom
# +   3. 95 000 000 Ft :  https://dh.hu/ingatlan/HZ520905/elado-haz-komarom-esztergom-megye-esztergom
# +   4. 89 000 000 Ft :  https://dh.hu/ingatlan/HZ419654/elado-haz-komarom-esztergom-megye-esztergom
# +   5. 79 990 000 Ft :  https://dh.hu/ingatlan/HZ484407/elado-haz-komarom-esztergom-megye-esztergom
# +   6. 69 990 000 Ft :  https://dh.hu/ingatlan/HZ494892/elado-haz-komarom-esztergom-megye-esztergom
# +   7. 64 500 000 Ft :  https://dh.hu/ingatlan/HZ522542/elado-haz-komarom-esztergom-megye-esztergom
# +   8. 60 000 000 Ft :  https://dh.hu/ingatlan/HZ015473/elado-haz-komarom-esztergom-megye-esztergom
# ...
