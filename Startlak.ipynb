# %% [markdown]
# <a href="https://colab.research.google.com/github/sipocz/ingatlan/blob/master/Startlak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import  BeautifulSoup


def querycity(city):
    print("------------------------------------------------")
    print("+    ",city.capitalize())


    prefix="https://www.startlak.hu/"
    url=prefix+city+"+elado+haz-hazresz+ar--70000000+dragabb"
    res=requests.get(url)
    #print (res.text)
    soup=BeautifulSoup(res.text,"html.parser")
  
    cardcontainer=soup.find_all("div", class_="cardContainer")
    #print(cardcontainer)
    urllist=[]
    pricelist=[]
    for cc in cardcontainer:
        urllist.append(""+cc.div.div.a["href"])
        pricecontainer=cc.find_all("div",class_="figFav")
        pricelist.append(pricecontainer[0]["data-price"])    
    
    #print(urllist)
    #print(pricelist)
    
    for cc in cardcontainer:
        pricelist.append(""+cc.div.div.a["href"])
    


    #pricelist=soup.find_all("span",itemprop="price")
    #print(pricelist)


    out1=[]
    out2={}
    for i in enumerate(urllist):
        link=prefix+i[1]
        print(i[0],". ",pricelist[i[0]],link)
       # out1.append([pricelist[i[0]].text,link])

        #out.append([urllist[i],pricelist[i]])
    

 #   print("----------------  END  ------------------------")


querycity("esztergom")
querycity("mogyorosbanya")
querycity("piliscsaba")
querycity("csolnok")
querycity("zsambek")
querycity("gyermely")
querycity("szomor")
querycity("csobanka")
querycity("tinnye")
querycity("pilisvorosvar")
querycity("solymar")
querycity("perbal")
querycity("pilisborosjeno")
# Out:
# ------------------------------------------------
# +     Esztergom
# 0 .  69200000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom+csendes-nyugott-festoi/6783801
# 1 .  69000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6464599
# 2 .  68000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6766866
# 3 .  65000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6357606
# 4 .  60000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom+szentgyorgymezo/6314003
# 5 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6438673
# 6 .  59000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom+belvaros/6480087
# 7 .  59000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6484883
# 8 .  58900000 https://www.startlak.hu//ingatlan/elado+sorhaz+esztergom/5911427
# 9 .  58000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6490857
# 10 .  58000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6730650
# 11 .  56990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom+pilisszentlelek/6512525
# 12 .  56990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6522305
# 13 .  56900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6389085
# 14 .  55000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6611365
# 15 .  50000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom+bubanat/6583752
# 16 .  49900000 https://www.startlak.hu//ingatlan/elado+sorhaz+esztergom+eszaki-varosresz/6515103
# 17 .  47000000 https://www.startlak.hu//ingatlan/elado+sorhaz+esztergom/6603995
# 18 .  47000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom/6607512
# 19 .  46900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+esztergom+bocskai-sor/6717705
# ------------------------------------------------
# +     Mogyorosbanya
# 0 .  39900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+mogyorosbanya+fo-ut/6584324
# ------------------------------------------------
# +     Piliscsaba
# 0 .  69900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6356743
# 1 .  69900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6389754
# 2 .  69900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6503923
# 3 .  69500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6605981
# 4 .  63945000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba+ferenc-forras-utja/6588073
# 5 .  61990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba+kenderesi-ut/6739636
# 6 .  61990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba+kenderesi-ut/6741144
# 7 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6682666
# 8 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba+uj-epitesu-ikerhazfel/6696075
# 9 .  59500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6604004
# 10 .  49900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+piliscsaba/6538087
# 11 .  49900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+piliscsaba+onallo-ikerhaz-fel/6624693
# 12 .  49900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba+piliscsaba-magdolnavolgy/6630456
# 13 .  49900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba+ikerhazfel-kerttel-elado/6651945
# 14 .  49900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6775180
# 15 .  47900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6250317
# 16 .  45000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6517651
# 17 .  40900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba+piliscsaba-garancsi-ut/6713166
# 18 .  34900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6766377
# 19 .  34900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+piliscsaba/6779532
# ------------------------------------------------
# +     Csolnok
# 0 .  48900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok/6440642
# 1 .  48900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok+ruckschuss-antal-utca/6441466
# 2 .  20500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok/6587498
# 3 .  20500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok/6660359
# 4 .  20500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok/6661545
# 5 .  17500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok/6770399
# 6 .  17000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok/6604717
# 7 .  12500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok/6750966
# 8 .  4900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csolnok+lakoovezet/6712632
# ------------------------------------------------
# +     Zsambek
# 0 .  69000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek+bethlen-gabor-utca/6571467
# 1 .  69000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek+zsambek-csendes-utcajaban/6573393
# 2 .  69000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6623941
# 3 .  66000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6722653
# 4 .  64990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6727120
# 5 .  64900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6575642
# 6 .  62900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6509879
# 7 .  62900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek+csendes-mellekutca/6763585
# 8 .  62900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6775467
# 9 .  62900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6780979
# 10 .  59990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6690674
# 11 .  59990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6727121
# 12 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6509857
# 13 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6534561
# 14 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek+zsambek-kozpont/6751203
# 15 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek+csendes-mellekutca/6764662
# 16 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek+csendes-mellekutca/6764667
# 17 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6771665
# 18 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6775495
# 19 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+zsambek/6775849
# ------------------------------------------------
# +     Gyermely
# 0 .  49900009 https://www.startlak.hu//ingatlan/elado+csaladi-haz+gyermely+csendes-utca/6634650
# 1 .  49900009 https://www.startlak.hu//ingatlan/elado+csaladi-haz+gyermely/6660222
# 2 .  26000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+gyermely+gyarmat-utca/6304162
# 3 .  26000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+gyermely+gyarmatpuszta/6324387
# ------------------------------------------------
# +     Szomor
# 0 .  38000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+szomor+csendes-kozpont/6489968
# 1 .  38000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+szomor/6494878
# 2 .  10000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+szomor+pesti-utca/6516723
# ------------------------------------------------
# +     Csobanka
# 0 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka+csobanka/6457077
# 1 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka/6563531
# 2 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka+csobanka/6603231
# 3 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka/6745669
# 4 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka/6745749
# 5 .  51900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka+maria-utca/6603848
# 6 .  50000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka+csobanka-park/6637529
# 7 .  41990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka+csobanka/6694923
# 8 .  39900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka+csobanka/6032856
# 9 .  38500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka/6700382
# 10 .  27500000 https://www.startlak.hu//ingatlan/elado+ikerhaz+csobanka+csobanka/6038148
# 11 .  19900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+csobanka/6745845
# ------------------------------------------------
# +     Tinnye
# 0 .  55900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+tinnye/6742860
# 1 .  44900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+tinnye/6480306
# 2 .  29950000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+tinnye+csaladi-haz-tinnyen/6433972
# 3 .  28000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+tinnye/6570350
# 4 .  26400000 https://www.startlak.hu//ingatlan/elado+ikerhaz+tinnye+matyas-kiraly-utca/6766081
# 5 .  26400000 https://www.startlak.hu//ingatlan/elado+ikerhaz+tinnye/6766084
# 6 .  23900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+tinnye+csaladi-haz-nagy-telekkel/6414134
# 7 .  23500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+tinnye+csaladi-haz-nagy-csaladnak/6410561
# ------------------------------------------------
# +     Pilisvorosvar
# 0 .  69900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar+pilisvorosvar/6617987
# 1 .  69900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6756217
# 2 .  68900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+pilisvorosvar/6655920
# 3 .  67900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar+pilisvorosvar/6753839
# 4 .  62000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6704068
# 5 .  62000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6709213
# 6 .  62000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6770291
# 7 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6618248
# 8 .  52000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6659330
# 9 .  45000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6782626
# 10 .  41900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6763239
# 11 .  35900000 https://www.startlak.hu//ingatlan/elado+hazresz+pilisvorosvar+csobankai-utca/6528570
# 12 .  34900000 https://www.startlak.hu//ingatlan/elado+sorhaz+pilisvorosvar/6538086
# 13 .  34900000 https://www.startlak.hu//ingatlan/elado+sorhaz+pilisvorosvar+ujszeru-sorhaz/6752916
# 14 .  30000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6684177
# 15 .  30000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6684179
# 16 .  29600000 https://www.startlak.hu//ingatlan/elado+hazresz+pilisvorosvar/6745468
# 17 .  24800000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6779899
# 18 .  21000000 https://www.startlak.hu//ingatlan/elado+ikerhaz+pilisvorosvar/6777686
# 19 .  19900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisvorosvar/6534633
# ------------------------------------------------
# +     Solymar
# 0 .  69900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+solymar/6614955
# 1 .  69800000 https://www.startlak.hu//ingatlan/elado+ikerhaz+solymar/6614956
# 2 .  69000000 https://www.startlak.hu//ingatlan/elado+ikerhaz+solymar/6716636
# 3 .  68000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar/6771197
# 4 .  59900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+solymar/6377740
# 5 .  59900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+solymar/6507126
# 6 .  59900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+solymar/6731697
# 7 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar/6771563
# 8 .  59500000 https://www.startlak.hu//ingatlan/elado+sorhaz+solymar/6773351
# 9 .  59000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar+anna-kapolna-kornyeke/6567797
# 10 .  59000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar/6590702
# 11 .  59000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar+solymar-panorama-u/6720282
# 12 .  49900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar/6700439
# 13 .  43900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar/6682456
# 14 .  43500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar/6539472
# 15 .  39900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar+hutweide/6718657
# 16 .  38800000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+solymar/6682457
# 17 .  35900000 https://www.startlak.hu//ingatlan/elado+hazresz+solymar/6501583
# 18 .  32990000 https://www.startlak.hu//ingatlan/elado+ikerhaz+solymar/6537524
# 19 .  8500000 https://www.startlak.hu//ingatlan/elado+hazresz+solymar/6553568
# ------------------------------------------------
# +     Perbal
# 0 .  69500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+perbal+fo-utca/6712716
# 1 .  48000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+perbal/6767785
# 2 .  34000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+perbal/6366079
# ------------------------------------------------
# +     Pilisborosjeno
# 0 .  67400000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno/6615210
# 1 .  62400000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno/6615208
# 2 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno+pilisborosjeno-panoramas/6598595
# 3 .  59900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+pilisborosjeno+pilisborosjeno/6599547
# 4 .  59900000 https://www.startlak.hu//ingatlan/elado+ikerhaz+pilisborosjeno/6653272
# 5 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno/6746531
# 6 .  59900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno/6750045
# 7 .  55000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno+csendes-panoramas/6561957
# 8 .  55000000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno+teglagyar/6724264
# 9 .  54990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno/6631211
# 10 .  54990000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno/6694529
# 11 .  47500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno/6553514
# 12 .  47500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno+ezusthegyi-ut/6555526
# 13 .  47500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno+nagykevely-alatt/6595012
# 14 .  47500000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno/6604333
# 15 .  29900000 https://www.startlak.hu//ingatlan/elado+csaladi-haz+pilisborosjeno+kozpontban/6699783
